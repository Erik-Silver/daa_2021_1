# %% [markdown]
# <a href="https://colab.research.google.com/github/Erik-Silver/daa_2021_1/blob/master/21Octubre_1511.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from time import time

def ejemplo1( n ):
  start_time = time()
  c = n + 1
  d = c * n
  e = n * n
  total = c + e - d
  print(f"total={ total }")
  elapsed_time = time() - start_time
  print("Tiempo transcurrido ejemplo 1: %0.10f segundos." % elapsed_time)

def ejemplo2( n ):
  start_time = time()
  contador = 0
  for i in range( n ) :
    for j in range( n ) :
      contador += 1
    elapsed_time = time() - start_time
    print("Tiempo transcurrido ejemplo 2: %0.10f segundos." % elapsed_time)
    return contador


def ejemplo3( n ): # n=4
    start_time = time()
    x = n * 2 # x = 8
    y = 0   # y = 0
    for m in range( 100 ): #3
      y = x - n   # y = 4
    elapsed_time = time() - start_time
    print("Tiempo transcurrido ejemplo 3: %0.10f segundos." % elapsed_time)
    return y

def ejemplo4( n ):
  start_time = time()
  x = 3 * 3.1416 + n
  y = x + 3 * 3 - n
  z = x + y
  elapsed_time = time() - start_time
  print("Tiempo transcurrido ejemplo 4: %0.10f segundos." % elapsed_time)
  return z


def ejemplo5( x ):
  start_time = time()
  n = 10
  for j in range( 0 , x , 1 ):
    n = j + n
    elapsed_time = time() - start_time
    print("Tiempo transcurrido ejemplo 5: %0.10f segundos." % elapsed_time)
    return n



def ejemplo6( n ):
    start_time = time()
    data=[[[1 for x in range(n)] for x in range(n)] 
          for x in range(n)]
    suma = 0
    for d in range(n):
      for r in range(n):
        for c in range(n):
          suma += data[d][r][c]
    elapsed_time = time() - start_time
    print("Tiempo transcurrido ejemplo 6: %0.10f segundos." % elapsed_time)
    return suma

# %%
for entrada in range(100,1100,100):
  print(f"Ejecucion con el numero {entrada} \n{ejemplo1( entrada )}-------------------------------------")

print("\n\n")

for entrada in range(100,1100,100):
  print(f"Ejecucion con el numero {entrada} \n{ejemplo2( entrada )}-------------------------------------")

print("\n\n")


for entrada in range(100,1100,100):
  print(f"Ejecucion con el numero {entrada} \n{ejemplo3( entrada )}-------------------------------------")

print("\n\n")


for entrada in range(100,1100,100):
  print(f"Ejecucion con el numero {entrada} \n{ejemplo4( entrada )}-------------------------------------")

print("\n\n")


for entrada in range(100,1100,100):
  print(f"Ejecucion con el numero {entrada} \n{ejemplo5( entrada )}-------------------------------------")

print("\n\n")


for entrada in range(100,1100,100):
  print(f"Ejecucion con el numero {entrada} \n{ejemplo6( entrada )}-------------------------------------")
# Out:
# total=1
# Tiempo transcurrido ejemplo 1: 0.0000894070 segundos.
# Ejecucion con el numero 100
# None-------------------------------------
# total=1
# Tiempo transcurrido ejemplo 1: 0.0000209808 segundos.
# Ejecucion con el numero 200
# None-------------------------------------
# total=1
# Tiempo transcurrido ejemplo 1: 0.0000193119 segundos.
# Ejecucion con el numero 300
# None-------------------------------------
# total=1
# Tiempo transcurrido ejemplo 1: 0.0000193119 segundos.
# Ejecucion con el numero 400
# None-------------------------------------
# total=1
# Tiempo transcurrido ejemplo 1: 0.0000195503 segundos.
# Ejecucion con el numero 500
# None-------------------------------------
# total=1
# Tiempo transcurrido ejemplo 1: 0.0000164509 segundos.
# Ejecucion con el numero 600
# None-------------------------------------
# total=1
# Tiempo transcurrido ejemplo 1: 0.0000166893 segundos.
# Ejecucion con el numero 700
# None-------------------------------------
# total=1
# ...
